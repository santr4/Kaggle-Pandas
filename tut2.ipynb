# %% [markdown]
# Indexing, Selecting and Assigning.

# %%
import pandas as pd
reviews = pd.read_csv('/home/aaranyak/Documents/10 year coding challenge/Kaggle-Pandas/Kaggle-Pandas/winequalityN.csv')

# %%
reviews
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.045                 45.0                 170.0  1.00100  3.00
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 4         0.058                 47.0                 186.0  0.99560  3.19
# ...         ...                  ...                   ...      ...   ...
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 0          0.45      8.8        6
# 1          0.49      9.5        6
# 2          0.44     10.1        6
# 3          0.40      9.9        6
# 4          0.40      9.9        6
# ...         ...      ...      ...
# 6492       0.58     10.5        5
# 6493        NaN     11.2        6
# 6494       0.75     11.0        6
# 6495       0.71     10.2        5
# 6496       0.66     11.0        6
#
# [6497 rows x 13 columns]

# %%
reviews.shape
# Out:
# (6497, 13)

# %% [markdown]
# In python we can access the properties of the objects.

# %%
reviews.pH
# Out:
# 0       3.00
# 1       3.30
# 2       3.26
# 3       3.19
# 4       3.19
#         ...
# 6492    3.45
# 6493    3.52
# 6494    3.42
# 6495    3.57
# 6496    3.39
# Name: pH, Length: 6497, dtype: float64

# %%
reviews['fixed acidity']
# Out:
# 0       7.0
# 1       6.3
# 2       8.1
# 3       7.2
# 4       7.2
#        ...
# 6492    6.2
# 6493    5.9
# 6494    6.3
# 6495    5.9
# 6496    6.0
# Name: fixed acidity, Length: 6497, dtype: float64

# %%
reviews['fixed acidity'][0]
# Out:
# 7.0

# %% [markdown]
# Indexing

# %%
reviews.iloc[0] # selecting the first row in the dataframe.
# Out:
# type                    white
# fixed acidity             7.0
# volatile acidity         0.27
# citric acid              0.36
# residual sugar           20.7
# chlorides               0.045
# free sulfur dioxide      45.0
# total sulfur dioxide    170.0
# density                 1.001
# pH                        3.0
# sulphates                0.45
# alcohol                   8.8
# quality                     6
# Name: 0, dtype: object

# %%
reviews.iloc[:,0]
# Out:
# 0       white
# 1       white
# 2       white
# 3       white
# 4       white
#         ...
# 6492      red
# 6493      red
# 6494      red
# 6495      red
# 6496      red
# Name: type, Length: 6497, dtype: object

# %%
reviews.iloc[:3,0]
# Out:
# 0    white
# 1    white
# 2    white
# Name: type, dtype: object

# %%
reviews.iloc[[1,2,3],0]
# Out:
# 1    white
# 2    white
# 3    white
# Name: type, dtype: object

# %%
reviews.iloc[-5:]
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 6492  red            6.2             0.600         0.08             2.0
# 6493  red            5.9             0.550         0.10             2.2
# 6494  red            6.3             0.510         0.13             2.3
# 6495  red            5.9             0.645         0.12             2.0
# 6496  red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 6492       0.58     10.5        5
# 6493        NaN     11.2        6
# 6494       0.75     11.0        6
# 6495       0.71     10.2        5
# 6496       0.66     11.0        6

# %% [markdown]
# label based selection.

# %%
reviews.loc[0,'volatile acidity']
# Out:
# 0.27

# %%
# because our dataset has important values that's why loc is more useful.
reviews.loc[:,['type','citric acid','chlorides']]
# Out:
#        type  citric acid  chlorides
# 0     white         0.36      0.045
# 1     white         0.34      0.049
# 2     white         0.40      0.050
# 3     white         0.32      0.058
# 4     white         0.32      0.058
# ...     ...          ...        ...
# 6492    red         0.08      0.090
# 6493    red         0.10      0.062
# 6494    red         0.13      0.076
# 6495    red         0.12      0.075
# 6496    red         0.47      0.067
#
# [6497 rows x 3 columns]

# %% [markdown]
# Note: iloc for 0:10 chooses from 0...9 whereas loc for 0:10 chooses from 0...10

# %% [markdown]
# Manipulating Index

# %%
reviews.set_index('type')
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# type
# white            7.0             0.270         0.36            20.7
# white            6.3             0.300         0.34             1.6
# white            8.1             0.280         0.40             6.9
# white            7.2             0.230         0.32             8.5
# white            7.2             0.230         0.32             8.5
# ...              ...               ...          ...             ...
# red              6.2             0.600         0.08             2.0
# red              5.9             0.550         0.10             2.2
# red              6.3             0.510         0.13             2.3
# red              5.9             0.645         0.12             2.0
# red              6.0             0.310         0.47             3.6
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# type
# white      0.045                 45.0                 170.0  1.00100  3.00
# white      0.049                 14.0                 132.0  0.99400  3.30
# white      0.050                 30.0                  97.0  0.99510  3.26
# white      0.058                 47.0                 186.0  0.99560  3.19
# white      0.058                 47.0                 186.0  0.99560  3.19
# ...          ...                  ...                   ...      ...   ...
# red        0.090                 32.0                  44.0  0.99490  3.45
# red        0.062                 39.0                  51.0  0.99512  3.52
# red        0.076                 29.0                  40.0  0.99574  3.42
# red        0.075                 32.0                  44.0  0.99547  3.57
# red        0.067                 18.0                  42.0  0.99549  3.39
#
#        sulphates  alcohol  quality
# type
# white       0.45      8.8        6
# white       0.49      9.5        6
# white       0.44     10.1        6
# white       0.40      9.9        6
# white       0.40      9.9        6
# ...          ...      ...      ...
# red         0.58     10.5        5
# red          NaN     11.2        6
# red         0.75     11.0        6
# red         0.71     10.2        5
# red         0.66     11.0        6
#
# [6497 rows x 12 columns]

# %% [markdown]
# Conditional Selection

# %%
reviews.loc[(reviews.chlorides > 0.050) & (reviews.quality == 5)]
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 23    white            7.6             0.670         0.14            1.50
# 35    white            7.3             0.280         0.43            1.70
# 36    white            6.5             0.390         0.23            5.40
# 38    white            7.3             0.240         0.39           17.95
# 39    white            7.3             0.240         0.39           17.95
# ...     ...            ...               ...          ...             ...
# 6480    red            6.1             0.715         0.10            2.60
# 6481    red            6.2             0.460         0.29            2.10
# 6487    red            6.6             0.725         0.20            7.80
# 6492    red            6.2             0.600         0.08            2.00
# 6495    red            5.9             0.645         0.12            2.00
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 23        0.074                 25.0                 168.0  0.99370  3.05
# 35        0.080                 21.0                 123.0  0.99050  3.19
# 36        0.051                 25.0                 149.0  0.99340  3.24
# 38        0.057                 45.0                 149.0  0.99990  3.21
# 39        0.057                 45.0                 149.0  0.99990  3.21
# ...         ...                  ...                   ...      ...   ...
# 6480      0.053                 13.0                  27.0  0.99362  3.57
# 6481      0.074                 32.0                  98.0  0.99578  3.33
# 6487      0.073                 29.0                  79.0  0.99770  3.29
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6495      0.075                 32.0                  44.0  0.99547  3.57
#
#       sulphates  alcohol  quality
# 23         0.51      9.3        5
# 35         0.42     12.8        5
# 36         0.35     10.0        5
# 38         0.36      8.6        5
# 39         0.36      8.6        5
# ...         ...      ...      ...
# 6480       0.50     11.9        5
# 6481       0.62      9.8        5
# 6487       0.54      9.2        5
# 6492       0.58     10.5        5
# 6495       0.71     10.2        5
#
# [1174 rows x 13 columns]

# %%
reviews.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
reviews.loc[reviews['fixed acidity'].isnull()]
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 17    white            NaN             0.660         0.48             1.2
# 174   white            NaN             0.270         0.31            17.7
# 249   white            NaN             0.410         0.14            10.4
# 267   white            NaN             0.580         0.07             6.9
# 368   white            NaN             0.290         0.48             2.3
# 518   white            NaN             0.130         0.28             1.9
# 1079  white            NaN               NaN         0.29             6.2
# 2902  white            NaN             0.360         0.14             8.9
# 6428    red            NaN             0.440         0.09             2.2
# 6429    red            NaN             0.705         0.10             2.8
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 17        0.029                 29.0                  75.0  0.98920  3.33
# 174       0.051                 33.0                 173.0  0.99900  3.09
# 249       0.037                 18.0                 119.0  0.99600  3.38
# 267       0.043                 34.0                 149.0  0.99440  3.34
# 368       0.049                 36.0                 178.0  0.99310  3.17
# 518       0.050                 20.0                  78.0  0.99180  3.43
# 1079      0.046                 29.0                 227.0  0.99520  3.29
# 2902      0.036                 38.0                 155.0  0.99622  3.27
# 6428      0.063                  9.0                  18.0  0.99444   NaN
# 6429      0.081                 13.0                  28.0  0.99631   NaN
#
#       sulphates  alcohol  quality
# 17         0.39     12.8        8
# 174        0.64     10.2        5
# 249        0.45     10.0        5
# 267        0.57      9.7        5
# 368        0.64     10.6        6
# 518        0.64     10.8        6
# 1079       0.53     10.1        6
# 2902        NaN      9.4        5
# 6428       0.69     11.3        6
# 6429       0.66     10.2        5

# %% [markdown]
# Assigning Data

# %%
reviews['pH'] = 600

# %%
reviews
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density   pH  \
# 0         0.045                 45.0                 170.0  1.00100  600
# 1         0.049                 14.0                 132.0  0.99400  600
# 2         0.050                 30.0                  97.0  0.99510  600
# 3         0.058                 47.0                 186.0  0.99560  600
# 4         0.058                 47.0                 186.0  0.99560  600
# ...         ...                  ...                   ...      ...  ...
# 6492      0.090                 32.0                  44.0  0.99490  600
# 6493      0.062                 39.0                  51.0  0.99512  600
# 6494      0.076                 29.0                  40.0  0.99574  600
# 6495      0.075                 32.0                  44.0  0.99547  600
# 6496      0.067                 18.0                  42.0  0.99549  600
#
#       sulphates  alcohol  quality
# 0          0.45      8.8        6
# 1          0.49      9.5        6
# 2          0.44     10.1        6
# 3          0.40      9.9        6
# 4          0.40      9.9        6
# ...         ...      ...      ...
# 6492       0.58     10.5        5
# 6493        NaN     11.2        6
# 6494       0.75     11.0        6
# 6495       0.71     10.2        5
# 6496       0.66     11.0        6
#
# [6497 rows x 13 columns]
